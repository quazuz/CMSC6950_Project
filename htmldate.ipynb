# %%
from htmldate import find_date

# %%
import pandas as pd
import numpy as np

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
import csv
df = pd.read_csv("dates.csv")
np_url = df['url'].values.tolist()
#print(df)
print(np_url)

dates = []
for url in np_url:
    date = find_date(url)
    dates.append(date)
    #print(date)
    for date in dates:
        print(date)
# Out:
# ['http://news.mit.edu/2020/faculty-receive-funding-develop-novel-ai-techniques-combat-covid-19-0717', 'http://news.mit.edu/2020/what-is-covid-19-data-tsunami-telling-policymakers-0701', 'http://news.mit.edu/2020/macro-eyes-vaccine-chain-health-equity-0626', 'http://news.mit.edu/2020/music-gesture-artificial-intelligence-identifies-melody-by-musician-body-language-0625', 'http://news.mit.edu/2020/ideastream-showcases-breakthrough-technologies-across-mit-0624', 'http://news.mit.edu/2020/mit-toyota-release-visual-open-data-accelerate-autonomous-driving-research-0618', 'http://news.mit.edu/2020/what-jumps-out-photo-changes-longer-we-look-0617', 'http://news.mit.edu/2020/machine-learning-map-ocean-0529']
# 2020-07-17
# 2020-07-17
# 2020-07-01
# 2020-07-17
# 2020-07-01
# 2020-06-25
# 2020-07-17
# 2020-07-01
# 2020-06-25
# 2020-06-25
# 2020-07-17
# 2020-07-01
# 2020-06-25
# 2020-06-25
# 2020-06-24
# 2020-07-17
# 2020-07-01
# 2020-06-25
# 2020-06-25
# 2020-06-24
# 2020-06-18
# 2020-07-17
# 2020-07-01
# 2020-06-25
# 2020-06-25
# 2020-06-24
# 2020-06-18
# 2020-06-17
# 2020-07-17
# 2020-07-01
# 2020-06-25
# 2020-06-25
# 2020-06-24
# 2020-06-18
# 2020-06-17
# 2020-05-29

# %% [markdown]
# ## Getting url names

# %%
from urllib.request import urlopen
from lxml.html import parse

url = 'http://news.mit.edu/2020/ideastream-showcases-breakthrough-technologies-across-mit-0624'
page = urlopen(url)
p = parse(page)
print (p.find(".//title").text)
# Out:
# IdeaStream 2020 goes virtual | MIT News

# %%
column = widgets.Dropdown(options=list(df['url']),description='Web Link')
ui = widgets.HBox([column])
def print_date(column):
    date = find_date(column)
    print(date)

out = widgets.interactive_output(print_date, {'column': column})

display(ui, out)
# Out:
# HBox(children=(Dropdown(description='Web Link', options=('http://news.mit.edu/2020/faculty-receive-funding-dev…
# Output()

# %%
# df.to_csv('dates.csv')   
import matplotlib
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(dates, np_url)

ax.set(ylabel='URL', xlabel='Dates',
       title='PLOT SHOWING PUBLICATION DATES OF DIFFERENT WEB ARTICLES')
ax.grid()

fig.savefig("test.png")
plt.show()
